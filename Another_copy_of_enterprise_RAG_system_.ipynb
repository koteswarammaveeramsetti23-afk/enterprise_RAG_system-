# %%
print("enterprise RAG system")
print("project started susscessfully!")
# Out:
# enterprise RAG system
# project started susscessfully!

# %%
# !pip install langchain langchain-community sentence-transformers faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 41.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 80.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
import pypdf
import langchain
import sentence_transformers
import faiss
print("libraries installed successfully!")
# Out:
# libraries installed successfully!

# %%
# %pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.5/395.5 kB 9.9 MB/s eta 0:00:00
# ...

# %%
import pypdf
print("pypdf installed successfully!")
# Out:
# pypdf installed successfully!

# %%
# !pip install -U reportlab

# %%
# !pip install reportlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 35.4 MB/s eta 0:00:00
# ...

# %%
from reportlab.pdfgen import canvas as pdfcanvas
pdf = pdfcanvas.Canvas("company_policy.pdf")
pdf.drawString(100, 750, "company leave policy")
pdf.drawString(100, 700, "employees are eligible for 20 paid leaves per year.")
pdf.drawString(100, 650, "employees can apply for leave through the HR portal.")
pdf.drawString(100, 600, "leave requests should normally be submitted two days before.")
pdf.drawString(100, 550, "emergency leave can be requested through the HR department.")
pdf.save()
print("PDF created successfully")
# Out:
# PDF created successfully

# %%
from reportlab.pdfgen import canvas as pdfcanvas
pdf = pdfcanvas.Canvas("company_policy.pdf")
pdf.drawString(100, 750, "company leave policy")
pdf.drawString(100, 700, "employees are eligible for 20 paid leaves per year.")
pdf.drawString(100, 650, "employees can apply for leave through the HR portal.")
pdf.drawString(100, 600, "leave requests should normally be submitted two days before.")
pdf.drawString(100, 550, "emergency leave can be requested through the HR department.")
pdf.save()
print("PDF created successfully")
# Out:
# PDF created successfully

# %%
# %pip install reportlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.2 MB/s eta 0:00:00
# ...

# %%
# %pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.5/395.5 kB 7.1 MB/s eta 0:00:00
# ...

# %%
# %pip uninstall pypdf -y
# %pip install -U pypdf
# Out:
# Found existing installation: pypdf 6.19.0
# Uninstalling pypdf-6.19.0:
#   Successfully uninstalled pypdf-6.19.0
# ...
#   Using cached pypdf-6.19.0-py3-none-any.whl.metadata (7.5 kB)
# Using cached pypdf-6.19.0-py3-none-any.whl (395 kB)
# ...

# %%
from pypdf import PdfReader
reader = PdfReader("company_policy.pdf")
print("Number of pages:", len(reader.pages))
# Out:
# Number of pages: 1

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'sample_data']

# %%
text = ""
for page in reader.pages:
    text += page.extract_text()
print(text)
# Out:
# company leave policy
# employees are eligible for 20 paid leaves per year.
# employees can apply for leave through the HR portal.
# leave requests should normally be submitted two days before.
# emergency leave can be requested through the HR department.

# %%
chunk_size = 100
chunks = []
for i in range(0, len(text),chunk_size):
   chunks.append(text[i:i + chunk_size])
   print("number of chunks:", len(chunks))
# Out:
# number of chunks: 1
# number of chunks: 2
# number of chunks: 3

# %%
for i, chunk in enumerate(chunks):
  print("chunk", i + 1)
  print(chunk)
  print("-----------")
# Out:
# chunk 1
# company leave policy
# employees are eligible for 20 paid leaves per year.
# employees can apply for lea
# -----------
# chunk 2
# ve through the HR portal.
# leave requests should normally be submitted two days before.
# emergency lea
# -----------
# chunk 3
# ve can be requested through the HR department.
#
# -----------

# %%
from typing import overload
chunk_size = 50
overlap =10
chunks =[]
start = 0
while start < len(text):
  end = start +chunk_size
  chunks.append(text[start:end])
  print("number of chunks:", len(chunks))
# Out:
# Streaming output truncated to the last 5000 lines.
# number of chunks: 42432370
# number of chunks: 42432371
# number of chunks: 42432372
# number of chunks: 42432373
# number of chunks: 42432374
# number of chunks: 42432375
# number of chunks: 42432376
# number of chunks: 42432377
# number of chunks: 42432378
# number of chunks: 42432379
# number of chunks: 42432380
# number of chunks: 42432381
# number of chunks: 42432382
# number of chunks: 42432383
# number of chunks: 42432384
# number of chunks: 42432385
# number of chunks: 42432386
# number of chunks: 42432387
# number of chunks: 42432388
# number of chunks: 42432389
# number of chunks: 42432390
# number of chunks: 42432391
# number of chunks: 42432392
# number of chunks: 42432393
# number of chunks: 42432394
# number of chunks: 42432395
# number of chunks: 42432396
# number of chunks: 42432397
# number of chunks: 42432398
# number of chunks: 42432399
# number of chunks: 42432400
# number of chunks: 42432401
# ...

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("all-miniLM-L6-v2")
print("Embedding model loaded successfully")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
embedding = model.encode(chunks)
print("Embeddings created succesfully!")
print("Numbers of embeddings:", len(embeddings))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13042/2897401957.py in <cell line: 0>()
# ----> 1 embedding = model.encode(chunks)
#       2 print("Embeddings created succesfully!")
#       3 print("Numbers of embeddings:", len(embeddings))
#
# NameError: name 'chunks' is not defined

# %%
text = ""
for page in reader.pages:
  page_text = page.extract_text()
  if page_text:
    text +=page_text
chunk_size = 50
oerlap = 10
chunks = []
for start in range(0,len(text),chunk_size - overlap):
  chunks.append(text[start:start + chunk_size])
print("numbers of chunks:",len(chunks))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13042/1075676595.py in <cell line: 0>()
#       1 text = ""
# ----> 2 for page in reader.pages:
#       3   page_text = page.extract_text()
#       4   if page_text:
#       5     text +=page_text
#
# NameError: name 'reader' is not defined

# %%
from pypdf import PdfReader
reader = PdfReader("company_policy.pdf")
text = ""
for page in reader.pages:
  page_text = page.extract_text()
  if page_text:
    text +=page_text
chunk_size = 50
overlap = 10
chunks = []
for start in range(0,len(text),chunk_size - overlap):
  chunks.append(text[start:start + chunk_size])
print("numbers of chunks:",len(chunks))
# Out:
# numbers of chunks: 7

# %%
embeddings = model.encode(chunks)
print("embeddings created successfully!")
print("number of embedding:",len(embeddings))
# Out:
# embeddings created successfully!
# number of embedding: 7

# %%
import faiss
import numpy as np
embedding_array = np.array(embedding).astype("float32")
dimension = embedding_array.shapes[1]
index = faiss.IndexFlatL2(dimension)
index.add(embedding_array)
print("FAISS index created successfully!")
print("Number of vectors:",index.ntotal)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13042/2229589432.py in <cell line: 0>()
#       1 import faiss
#       2 import numpy as np
# ----> 3 embedding_array = np.array(embedding).astype("float32")
#       4 dimension = embedding_array.shapes[1]
#       5 index = faiss.IndexFlatL2(dimension)
#
# NameError: name 'embedding' is not defined

# %%
# %pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 58.7 MB/s eta 0:00:00
# ...

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("all-miniLM-L6-v2")
embeddings = model.encode(chunks)
print("Embeddings created successfully!")
print("Number of embeddings:",len(embeddings))
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Embeddings created successfully!
# Number of embeddings: 7

# %%
import faiss
import numpy as np
embedding_array = np.array(embeddings).astype("float32")
dimension = embedding_array.shape[1]
index = faiss. IndexFlatL2(dimension)
index.add(embedding_array)
print("FAISS index created successfully!")
print("Number of  vectors:",index.ntotal)
# Out:
# FAISS index created successfully!
# Number of  vectors: 7

# %%
query = "How many paid leaves do employees get?"
query_embedding = model.encode([query])
distance, indices = index.search(np.array(query_embedding).astype("float32"),
k=2
)
print("Most relevant chunks:")
for i in indices[0]:
  print()
# Out:
# Most relevant chunks:
# ble for 20 paid leaves per year.
# employees can app
# ------------------
# company leave policy
# employees are eligible for 20
# ------------------

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key)
response = client.response.create(
model ="gpt-5.6-luna",
instrunctions ="answer only using the provided context. if the answer is not in the context, say you dont know.",
   input=f"""
 context:
 {context}
 question:
 {query}
 """
)
print("response.output_text")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3666/1056876291.py in <cell line: 0>()
#       1 from openai import OpenAI
#       2 client = OpenAI(api_key=api_key)
# ----> 3 response = client.response.create(
#       4 model ="gpt-5.6-luna",
#       5 instrunctions ="answer only using the provided context. if the answer is not in the context, say you dont know.",
#
# AttributeError: 'OpenAI' object has no attribute 'response'

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key)
response = client.response.create(
model ="gpt-5.6-luna",
instrunctions ="answer only using the provided context. if the answer is not in the context, say you dont know.",
   input=f"""
 context:
 {context}
 question:
 {query}
 """
)
print("response.output_text")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3666/1347986560.py in <cell line: 0>()
#       1 from openai import OpenAI
#       2 client = OpenAI(api_key=api_key)
# ----> 3 response = client.response.create(
#       4 model ="gpt-5.6-luna",
#       5 instrunctions ="answer only using the provided context. if the answer is not in the context, say you dont know.",
#
# AttributeError: 'OpenAI' object has no attribute 'response'

# %%
print(type(client))
print(hasattr(client,"responses"))
# Out:
# <class 'openai.OpenAI'>
# True

# %%
response = client.responses.create(
    model="gpt-5.6=luna",
    input=f"""
Context:
{context}

Question:
{query}

Answer only from the context.
"""
)
print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3666/3810920479.py in <cell line: 0>()
#       3     input=f"""
#       4 Context:
# ----> 5 {context}
#       6
#       7 Question:
#
# NameError: name 'context' is not defined

# %%
query = "How many paid leaves do employees get?"
query_embedding = model.encode([query])
distance,indices = index.search(np.array(query_embedding).astype("floats32"),
                               k=2
                                )
print("search completed!")
print(indices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3666/187957154.py in <cell line: 0>()
#       1 query = "How many paid leaves do employees get?"
# ----> 2 query_embedding = model.encode([query])
#       3 distance,indices = index.search(np.array(query_embedding).astype("floats32"),
#       4                                k=2
#       5                                 )
#
# NameError: name 'model' is not defined

# %%
# %pip install -U openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 21.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 2.54.0
#     Uninstalling openai-2.54.0:
#       Successfully uninstalled openai-2.54.0
# ...

# %%
# %pip uninstall -y openai
# %pip install openai
# Out:
# Found existing installation: openai 3.19.0
# Uninstalling openai-3.19.0:
#   Successfully uninstalled openai-3.19.0
# ...
#   Using cached openai-3.19.0-py3-none-any.whl.metadata (43 kB)
# ...
# Using cached openai-3.19.0-py3-none-any.whl (2.1 MB)
# ...

# %%
from openai import OpenAI
print("openAI imorted successfully")
# Out:
# openAI imorted successfully

# %%
from google.colab import userdata
from openai import OpenAI
api_key = userdata.get("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)
print("OpenAI client created successfully!")
# Out:
# OpenAI client created successfully!

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("all-miniLm-L6-v2")
print("Model loaded successfully!")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
import faiss
import numpy as np
print("FAISS ready!")
# Out:
# FAISS ready!

# %%
# %pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 38.6 MB/s eta 0:00:00
# ...

# %%
# %pip install -U sentence-transformes
# Out:
# ERROR: Could not find a version that satisfies the requirement sentence-transformes (from versions: none)
# ERROR: No matching distribution found for sentence-transformes

# %%
from pypdf import PdfReader

reader = PdfReader("company_policy.pdf")

print("Number of pages:", len(reader.pages))
# Out:
# Number of pages: 1

# %%
# %pip install -q pypdf reportlab sentence-transformers faiss-cpu openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.5/395.5 kB 22.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 72.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 74.3 MB/s eta 0:00:00

# %%
from pypdf import PdfReader
from reportlab.pdfgen import canvas
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
from openai import OpenAI
print("All packages ready!")
# Out:
# All packages ready!

# %%
from reportlab.pdfgen import canvas as pdfcanvas

pdf = pdfcanvas.Canvas("company_policy.pdf")

pdf.drawString(100, 750, "Company Leave Policy")
pdf.drawString(100, 700, "Employees are eligible for 20 paid leaves per year.")
pdf.drawString(100, 650, "Employees can apply for leave through the HR portal.")
pdf.drawString(100, 600, "Leave requests should normally be submitted two days before.")
pdf.drawString(100, 550, "Emergency leave can be requested through the HR department.")

pdf.save()

print("PDF created successfully!")
# Out:
# PDF created successfully!

# %%
# %pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.5/395.5 kB 5.8 MB/s eta 0:00:00
# ...

# %%
text = ""

for page in reader.pages:
    text += page.extract_text()

print(text)
# Out:
# Company Leave Policy
# Employees are eligible for 20 paid leaves per year.
# Employees can apply for leave through the HR portal.
# Leave requests should normally be submitted two days before.
# Emergency leave can be requested through the HR department.

# %%
chunk_size = 50
overlap = 10

chunks = []

for start in range(0, len(text), chunk_size - overlap):
    chunks.append(text[start:start + chunk_size])

print("Number of chunks:", len(chunks))
# Out:
# Number of chunks: 7

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

embeddings = model.encode(chunks)

print("Embeddings created successfully!")
print("Number of embeddings:", len(embeddings))
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
import faiss
import numpy as np

embedding_array = np.array(embeddings).astype("float32")

dimension = embedding_array.shape[1]

index = faiss.IndexFlatL2(dimension)

index.add(embedding_array)

print("FAISS index created successfully!")
print("Number of vectors:", index.ntotal)
# Out:
# FAISS index created successfully!
# Number of vectors: 7

# %%
query = "How many paid leaves do employees get?"

query_embedding = model.encode([query])

distances, indices = index.search(
    np.array(query_embedding).astype("float32"),
    k=2
)

print("Most relevant chunks:")

for i in indices[0]:
    print(chunks[i])
    print("----------------")
# Out:
# Most relevant chunks:
# ble for 20 paid leaves per year.
# Employees can app
# ----------------
# Company Leave Policy
# Employees are eligible for 20
# ----------------

# %%
context = "\n".join([chunks[i] for i in indices[0]])

print("Context created successfully!")
print(context)
# Out:
# Context created successfully!
# ble for 20 paid leaves per year.
# Employees can app
# Company Leave Policy
# Employees are eligible for 20

# %%
from google.colab import userdata
from openai import OpenAI

api_key = userdata.get("OPENAI_API_KEY")

client = OpenAI(api_key=api_key)

print("OpenAI client ready!")
# Out:
# OpenAI client ready!

# %%
 response = client.responses.create(
    model="gpt-5.6-luna",
    input=f"""
Context:
{context}

Question:
{query}

Answer only using the context. If the answer is not in the context, say "I don't know."
"""
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_4053/3083125090.py in <cell line: 0>()
# ----> 1 response = client.responses.create(
#       2    model="gpt-5.6-luna",
#       3    input=f"""
#       4 Context:
#       5 {context}
#
# /usr/local/lib/python3.13/dist-packages/openai/resources/responses/responses.py in create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#    1014         timeout: float | httpx.Timeout | None | NotGiven = not_given,
# ...

# %%
from google.colab import userdata

api_key = userdata.get("OPENAI_API_KEY")

print("API key loaded:", api_key is not None)
# Out:
# API key loaded: True

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)

print("Client created successfully!")
# Out:
# Client created successfully!

# %%
response = client.responses.create(
    model="gpt-5.6-luna",
    input="What is Python? Answer in one simple sentence."
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_4053/1536969009.py in <cell line: 0>()
# ----> 1 response = client.responses.create(
#       2     model="gpt-5.6-luna",
#       3     input="What is Python? Answer in one simple sentence."
#       4 )
#       5
#
# /usr/local/lib/python3.13/dist-packages/openai/resources/responses/responses.py in create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
# ...

# %%
response = client.responses.create(
    model="gpt-5.6-luna",
    input="What is Python? Answer in one simple sentence."
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_4053/1536969009.py in <cell line: 0>()
# ----> 1 response = client.responses.create(
#       2     model="gpt-5.6-luna",
#       3     input="What is Python? Answer in one simple sentence."
#       4 )
#       5
#
# /usr/local/lib/python3.13/dist-packages/openai/resources/responses/responses.py in create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
# ...

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)

response = client.responses.create(
    model="gpt-5.6-luna",
    input="What is Python? Answer in one simple sentence."
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_4053/2624605939.py in <cell line: 0>()
#       3 client = OpenAI(api_key=api_key)
#       4
# ----> 5 response = client.responses.create(
#       6     model="gpt-5.6-luna",
#       7     input="What is Python? Answer in one simple sentence."
#
# /usr/local/lib/python3.13/dist-packages/openai/resources/responses/responses.py in create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
# ...

# %%
# %pip install -q transformers sentencepiece

# %%
# %pip install -q transformers sentencepiece

# %%
from google.colab import userdata
api_key = userdata.get("OPENAI_API_KEY")

print("API key loaded:", api_key is not None)
# Out:
# API key loaded: True

# %%
from google.colab import userdata
from openai import OpenAI

api_key = userdata.get("OPENAI_API_KEY").strip()

client = OpenAI(api_key=api_key)

print("Client ready!")
# Out:
# Client ready!

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "google/flan-t5-small"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

print("Local LLM loaded successfully!")
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model: reconstructing file:   0%|          |  0.00B /  792kB
# spiece.model: downloading bytes:           |  0.00B
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  308MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/190 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Local LLM loaded successfully!

# %%
question = "What is Python?"

inputs = tokenizer(question, return_tensors="pt")

outputs = model.generate(
    **inputs,
    max_new_tokens=50
)

answer = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("Answer:", answer)
# Out:
# Answer: Python (disambiguation) Python is a syllable of arithmetic.

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

print("Embedding model loaded!")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Embedding model loaded!

# %%
query = "How many paid leaves do employees get?"

query_embedding = embedding_model.encode([query])

distances, indices = index.search(
    np.array(query_embedding).astype("float32"),
    k=2
)

context = "\n".join([chunks[i] for i in indices[0]])

print("Context:")
print(context)
# Out:
# Context:
# ble for 20 paid leaves per year.
# Employees can app
# Company Leave Policy
# Employees are eligible for 20

# %%
prompt = f"""
Answer the question using only the context below.

Context:
{context}

Question:
{query}

Answer:
"""

inputs = tokenizer(prompt, return_tensors="pt")

outputs = model.generate(
    **inputs,
    max_new_tokens=50
)

answer = tokenizer.decode(
    outputs[0],
    skip_special_tokens=True
)

print("Answer:", answer)
# Out:
# Answer: 20

# %%
def ask_rag(question):

    query_embedding = embedding_model.encode([question])

    distances, indices = index.search(
        np.array(query_embedding).astype("float32"),
        k=2
    )

    context = "\n".join([chunks[i] for i in indices[0]])

    prompt = f"""
Answer the question using only the context below.

Context:
{context}

Question:
{question}

Answer:
"""

    inputs = tokenizer(prompt, return_tensors="pt")

    outputs = model.generate(
        **inputs,
        max_new_tokens=50
    )

    answer = tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
    )

    return answer

print("RAG function created successfully!")
# Out:
# RAG function created successfully!

# %%
question = "How many paid leaves do employees get?"

answer = ask_rag(question)

print("Question:", question)
print("Answer:", answer)
# Out:
# Question: How many paid leaves do employees get?
# Answer: 20

# %%
# %pip install -q gradio

# %%
import gradio as gr

def chatbot(question):
    return ask_rag(question)

demo = gr.Interface(
    fn=chatbot,
    inputs=gr.Textbox(
        label="Ask a question",
        placeholder="Ask something about the company policy..."
    ),
    outputs=gr.Textbox(label="Answer"),
    title="Company Policy RAG Chatbot",
    description="Ask questions about the company policy document."
)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ae00f875fffc3692c6.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ae00f875fffc3692c6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
prompt = f"""def
 ask_rag_with_source(question):
query_embedding = embedding_model.encode([question])
   distances, indices = index.search(
   np.array(query_embedding).astype("float32")
   k=2
   )
   context ="\n".join([chunks[i] for i in indices[0]])
   context:
   {context}
   Question:
   {question}
   answer:
   """
   inputs = tokenizer(prompt,return_tensors="pt")
   outputs = model.generate(**inputs,max_new_tokens=50
   )
   answer = tokenizer.decode(outputs[0],skip_special_tokens=true
                             )
   source = "company_policy.pdf | page 1"
   return answer,source
# Out:
#   File "/tmp/ipykernel_4053/192069423.py", line 15
#     inputs = tokenizer(prompt,return_tensors="pt")
#     ^
# IndentationError: unexpected indent

# %%
def ask_rag_with_source(question):
    query_embedding = embedding_model.encode([question])

    distances, indices = index.search(
        np.array(query_embedding).astype("float32"),
        k=2
    )

    context = "\n".join([chunks[i] for i in indices[0]])

    prompt = f"""
Answer the question using only the context below.

Context:
{context}

Question:
{question}

Answer:
"""

    inputs = tokenizer(prompt, return_tensors="pt")

    outputs = model.generate(
        **inputs,
        max_new_tokens=50
    )

    answer = tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
    )

    source = "company_policy.pdf | page 1"

    return answer, source


answer, source = ask_rag_with_source(
    "How many paid leaves do employees get?"
)

print("Answer:", answer)
print("Source:", source)
# Out:
# Answer: 20
# Source: company_policy.pdf | page 1

# %%
import gradio as gr

def chatbot(question):
    answer, source = ask_rag_with_source(question)

    return answer, source


demo = gr.Interface(
    fn=chatbot,
    inputs=gr.Textbox(
        label="Ask a question",
        placeholder="Ask something about the company policy..."
    ),
    outputs=[
        gr.Textbox(label="Answer"),
        gr.Textbox(label="Source")
    ],
    title="Company Policy RAG Chatbot",
    description="Ask questions about the company policy document."
)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://55e6d0f1392888fd24.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://55e6d0f1392888fd24.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def chatbot(question):
    answer, source = ask_rag_with_source(question)

    final_answer = f"{answer}\n\n📄 Source: {source}"

    return final_answer


demo = gr.Interface(
    fn=chatbot,
    inputs=gr.Textbox(
        label="Ask a question",
        placeholder="Ask something about the company policy..."
    ),
    outputs=gr.Textbox(label="Answer"),
    title="Company Policy RAG Chatbot",
    description="Ask questions about the company policy document."
)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://59192cd97b368f16c4.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://59192cd97b368f16c4.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import sqlite3

conn = sqlite3.connect("rag_chatbot.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS chat_history (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    question TEXT,
    answer TEXT,
    source TEXT
)
""")

conn.commit()

print("SQL database created successfully!")
# Out:
# SQL database created successfully!

# %%
def save_chat(question, answer, source):
    cursor.execute(
        """
        INSERT INTO chat_history (question, answer, source)
        VALUES (?, ?, ?)
        """,
        (question, answer, source)
    )

    conn.commit()

    print("Chat saved successfully!")

# %%
save_chat(
    "How many paid leaves do employees get?",
    "Employees are eligible for 20 paid leaves per year.",
    "company_policy.pdf | page 1"
)
# Out:
# Chat saved successfully!

# %%
cursor.execute("SELECT * FROM chat_history")

rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'How many paid leaves do employees get?', 'Employees are eligible for 20 paid leaves per year.', 'company_policy.pdf | page 1')

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    username TEXT UNIQUE,
    password TEXT,
    role TEXT
)
""")

conn.commit()

print("Users table created successfully!")
# Out:
# Users table created successfully!

# %%
cursor.execute("""
INSERT OR IGNORE INTO users (username, password, role)
VALUES (?, ?, ?)
""", ("admin", "admin123", "admin"))

cursor.execute("""
INSERT OR IGNORE INTO users (username, password, role)
VALUES (?, ?, ?)
""", ("user", "user123", "user"))

conn.commit()

print("Users created successfully!")
# Out:
# Users created successfully!

# %%
def login(username, password):

    cursor.execute(
        """
        SELECT role FROM users
        WHERE username = ? AND password = ?
        """,
        (username, password)
    )

    result = cursor.fetchone()

    if result:
        return result[0]
    else:
        return None


role = login("admin", "admin123")

if role:
    print("Login successful!")
# Out:
# Login successful!

# %%
import sqlite3

conn = sqlite3.connect("rag_database.db")

cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS chat_history (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    question TEXT,
    answer TEXT,
    source TEXT
)
""")

conn.commit()
print("SQL database created successfully!")
# Out:
# SQL database created successfully!

# %%
question = "How many paid leaves do employees get?"
answer = "20"
source = "company_policy.pdf | page 1"

cursor.execute("""
INSERT INTO chat_history (question, answer, source)
VALUES (?, ?, ?)
""", (question, answer, source))

conn.commit()

print("Chat saved successfully!")
# Out:
# Chat saved successfully!

# %%
cursor.execute("SELECT * FROM chat_history")

rows = cursor.fetchall()

for row in rows:
    print("ID:", row[0])
    print("Question:", row[1])
    print("Answer:", row[2])
    print("Source:", row[3])
    print("-------------------")
# Out:
# ID: 1
# Question: How many paid leaves do employees get?
# Answer: 20
# Source: company_policy.pdf | page 1
# -------------------

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    username TEXT UNIQUE,
    password TEXT,
    role TEXT
)
""")

conn.commit()

print("Users table created successfully!")
# Out:
# Users table created successfully!

# %%
# Create Admin user
cursor.execute("""
INSERT OR IGNORE INTO users (username, password, role)
VALUES (?, ?, ?)
""", ("admin", "admin123", "admin"))

# Create Normal user
cursor.execute("""
INSERT OR IGNORE INTO users (username, password, role)
VALUES (?, ?, ?)
""", ("user", "user123", "user"))

conn.commit()

print("Admin and User created successfully!")
# Out:
# Admin and User created successfully!

# %%
def login(username, password):

    cursor.execute("""
    SELECT role
    FROM users
    WHERE username = ? AND password = ?
    """, (username, password))

    result = cursor.fetchone()

    if result:
        return result[0]
    else:
      return none
    role = login("admin", "admin123")
    if role:
      print("login successfully!")
      print("role:", role)
    else:
      print("inavalid username or password")

# %%
role = login("admin", "admin123")

print("Role:", role)
# Out:
# Role: admin

# %%
import gradio as gr

def check_login(username, password):
    role = login(username, password)

    if role:
        return f"Login successful! Role: {role}"
    else:
        return "Invalid username or password"


login_demo = gr.Interface(
    fn=check_login,
    inputs=[
        gr.Textbox(label="Username"),
        gr.Textbox(label="Password", type="password")
    ],
    outputs=gr.Textbox(label="Login Status"),
    title="RAG Chatbot Login"
)

login_demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://304e2ebd62eb685028.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://304e2ebd62eb685028.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
print(check_login("admin", "admin123"))
# Out:
# Login successful! Role: admin

# %%
def login(username, password):
    if username == "admin" and password == "1234":
        return "Login successful"
    else:
        return "Invalid username or password"


def check_login(username, password):
    return login(username, password)


demo = gr.Interface(
    fn=check_login,
    inputs=[
        gr.Textbox(label="Username"),
        gr.Textbox(label="Password", type="password")
    ],
    outputs=gr.Textbox(label="Login Status"),
    title="RAG Chatbot Login"
)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://32d0b6295a381d0001.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://32d0b6295a381d0001.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
chat_history = []

print("Chat history ready!")
# Out:
# Chat history ready!

# %%
def save_chat(question, answer):
    chat_history.append({
        "question": question,
        "answer": answer
    })

    print("Chat saved successfully!")


save_chat(
    "How many paid leaves do employees get?",
    "20"
)

print(chat_history)
# Out:
# Chat saved successfully!
# [{'question': 'How many paid leaves do employees get?', 'answer': '20'}]

# %%
def ask_rag_with_history(question):
    answer, source = ask_rag_with_source(question)

    save_chat(question, answer)

    return answer, source

# %%
def ask_rag_with_source(question):

    query_embedding = embedding_model.encode([question])

    distances, indices = index.search(
        np.array(query_embedding).astype("float32"),
        k=2
    )

    context = "\n".join([chunks[i] for i in indices[0]])

    prompt = f"""
Answer the question using only the context below.
Context:
{context}

Question:
{question}

answer"
"""
    inputs = tokenizer(prompt,return_tensors="pt")
    outputs = model.generate(**inputs,max_new_tokens=50
                             )
    answer = tokenizer.decode(outputs[0], skip_special_tokens=true
                              )
    source = "company_policy.pdf | page 1"
    return answer,source
    print("ask_rag_with_source ready!")

# %%
def ask_rag_with_source(question):

    query_embedding = embedding_model.encode([question])

    distances, indices = index.search(
        np.array(query_embedding).astype("float32"),
        k=2
    )

    context = "\n".join([chunks[i] for i in indices[0]])

    prompt = f"""
Answer the question using only the context below.
Context:
{context}

Question:
{question}

answer"
"""
    inputs = tokenizer(prompt,return_tensors="pt")
    outputs = model.generate(**inputs,max_new_tokens=50
                             )
    answer = tokenizer.decode(outputs[0], skip_special_tokens=true
                              )
    source = "company_policy.pdf | page 1"
    return answer,source
    print("ask_rag_with_source ready!")

# %%
print("Test")
# Out:
# Test

# %%
def ask_rag_with_source(question):
    return "test answer", "test source"

print("ask_rag_with_source ready!")
# Out:
# ask_rag_with_source ready!

# %%
print("embedding_model:", type(embedding_model))
print("index vectors:", index.ntotal)
print("chunks:", len(chunks))
print("tokenizer ready:", tokenizer is not None)
print("LLM ready:", model is not None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_643/3774176400.py in <cell line: 0>()
# ----> 1 print("embedding_model:", type(embedding_model))
#       2 print("index vectors:", index.ntotal)
#       3 print("chunks:", len(chunks))
#       4 print("tokenizer ready:", tokenizer is not None)
#       5 print("LLM ready:", model is not None)
#
# NameError: name 'embedding_model' is not defined

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

print("Embedding model loaded successfully!")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
print("Embedding model:", type(embedding_model))
print("FAISS vectors:", index.ntotal)
print("Number of chunks:", len(chunks))
# Out:
# Embedding model: <class 'sentence_transformers.sentence_transformer.model.SentenceTransformer'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_643/3770519974.py in <cell line: 0>()
#       1 print("Embedding model:", type(embedding_model))
# ----> 2 print("FAISS vectors:", index.ntotal)
#       3 print("Number of chunks:", len(chunks))
#
# NameError: name 'index' is not defined

# %%
import faiss
import numpy as np

embedding_array = np.array(
    embedding_model.encode(chunks)
).astype("float32")

dimension = embedding_array.shape[1]

index = faiss.IndexFlatL2(dimension)

index.add(embedding_array)

print("FAISS index created successfully!")
print("Number of vectors:", index.ntotal)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_643/1987422636.py in <cell line: 0>()
# ----> 1 import faiss
#       2 import numpy as np
#       3
#       4 embedding_array = np.array(
#       5     embedding_model.encode(chunks)
#
# ModuleNotFoundError: No module named 'faiss'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %pip install -q faiss-cpu

# %%
import faiss
import numpy as np

print("FAISS ready!")
# Out:
# FAISS ready!

# %%
embedding_array = np.array(
    embedding_model.encode(chunks)
).astype("float32")

dimension = embedding_array.shape[1]

index = faiss.IndexFlatL2(dimension)
index.add(embedding_array)

print("FAISS index created successfully!")
print("Number of vectors:", index.ntotal)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_643/1122296828.py in <cell line: 0>()
#       1 embedding_array = np.array(
# ----> 2     embedding_model.encode(chunks)
#       3 ).astype("float32")
#       4
#       5 dimension = embedding_array.shape[1]
#
# NameError: name 'chunks' is not defined

# %%
from pypdf import PdfReader

reader = PdfReader("company_policy.pdf")

text = ""

for page in reader.pages:
    text += page.extract_text()

print("PDF text loaded!")
print(text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_643/2997420728.py in <cell line: 0>()
# ----> 1 from pypdf import PdfReader
#       2
#       3 reader = PdfReader("company_policy.pdf")
#       4
#       5 text = ""
#
# ModuleNotFoundError: No module named 'pypdf'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.5/395.5 kB 9.5 MB/s eta 0:00:00
# ...

# %%
from pypdf import PdfReader

reader = PdfReader("company_policy.pdf")

text = ""

for page in reader.pages:
    text += page.extract_text()

print("PDF text loaded!")
print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_643/2997420728.py in <cell line: 0>()
#       1 from pypdf import PdfReader
#       2
# ----> 3 reader = PdfReader("company_policy.pdf")
#       4
#       5 text = ""
#
# /usr/local/lib/python3.13/dist-packages/pypdf/_reader.py in __init__(self, stream, strict, password, root_object_recovery_limit)
#     149         self._validated_root: Optional[DictionaryObject] = None
#     150
# --> 151         self._initialize_stream(stream)
#     152         self._known_objects: set[tuple[int, int]] = set()
#     153
#
# /usr/local/lib/python3.13/dist-packages/pypdf/_reader.py in _initialize_stream(self, stream)
#     170         self._stream_opened = False
#     171         if isinstance(stream, (str, Path)):
# --> 172             with open(stream, "rb") as fh:
#     173                 stream = BytesIO(fh.read())
# ...

# %%
# %pip install -q reportlab
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.6 MB/s eta 0:00:00

# %%
from reportlab.pdfgen import canvas as pdfcanvas

pdf = pdfcanvas.Canvas("company_policy.pdf")

pdf.drawString(100, 750, "Company Leave Policy")
pdf.drawString(100, 700, "Employees are eligible for 20 paid leaves per year.")
pdf.drawString(100, 650, "Employees can apply for leave through the HR portal.")
pdf.drawString(100, 600, "Leave requests should normally be submitted two days before.")
pdf.drawString(100, 550, "Emergency leave can be requested through the HR department.")

pdf.save()

print("Company policy PDF created successfully!")
# Out:
# Company policy PDF created successfully!

# %%
from pypdf import PdfReader

reader = PdfReader("company_policy.pdf")

text = ""

for page in reader.pages:
    text += page.extract_text()

print("PDF text loaded!")
print(text)
# Out:
# PDF text loaded!
# Company Leave Policy
# Employees are eligible for 20 paid leaves per year.
# Employees can apply for leave through the HR portal.
# Leave requests should normally be submitted two days before.
# Emergency leave can be requested through the HR department.

# %%
chunk_size = 50
overlap = 10

chunks = []

for start in range(0, len(text), chunk_size - overlap):
    chunks.append(text[start:start + chunk_size])

print("Number of chunks:", len(chunks))
# Out:
# Number of chunks: 7

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

embeddings = embedding_model.encode(chunks)

print("Embeddings created successfully!")
print("Number of embeddings:", len(embeddings))
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Embeddings created successfully!
# Number of embeddings: 7

# %%
import faiss
import numpy as np

embedding_array = np.array(embeddings).astype("float32")

dimension = embedding_array.shape[1]

index = faiss.IndexFlatL2(dimension)

index.add(embedding_array)

print("FAISS index created successfully!")
print("Number of vectors:", index.ntotal)
# Out:
# FAISS index created successfully!
# Number of vectors: 7

# %%
query = "How many paid leaves do employees get?"

query_embedding = embedding_model.encode([query])

distances, indices = index.search(
    np.array(query_embedding).astype("float32"),
    k=2
)

print("Most relevant chunks:")

for i in indices[0]:
    print(chunks[i])
    print("----------------")
# Out:
# Most relevant chunks:
# ble for 20 paid leaves per year.
# Employees can app
# ----------------
# Company Leave Policy
# Employees are eligible for 20
# ----------------

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "google/flan-t5-small"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

print("Local LLM loaded successfully!")
# Out:
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model: reconstructing file:   0%|          |  0.00B /  792kB
# spiece.model: downloading bytes:           |  0.00B
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  308MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/190 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Local LLM loaded successfully!

# %%
def ask_rag(question):

    # 1. Question embedding
    query_embedding = embedding_model.encode([question])

    # 2. Search relevant chunks
    distances, indices = index.search(
        np.array(query_embedding).astype("float32"),
        k=2
    )

    # 3. Create context
    context = "\n".join([chunks[i] for i in indices[0]])
    prompt = f"""
    answer the question using  only the context below
    Context:
    {context}
    Questoin:
    {question}
    answer:
    """

inputs = tokenizer(prompt,return_tensors="pt")
outputs = model.generate(**inputs,max_new_tokenizer=50
                                )

answer = tokenizer.decode(outputs[0], skip_special_tokens=true
                                 )
return answer
print("complete RAG pipline ready!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_643/97686953.py in <cell line: 0>()
#      21     """
#      22
# ---> 23 inputs = tokenizer(prompt,return_tensors="pt")
#      24 outputs = model.generate(**inputs,max_new_tokenizer=50
#      25                                 )
#
# NameError: name 'prompt' is not defined

# %%
def ask_rag(question):

    # 1. Question embedding
    query_embedding = embedding_model.encode([question])

    # 2. Search relevant chunks
    distances, indices = index.search(
        np.array(query_embedding).astype("float32"),
        k=2
    )

    # 3. Create context
    context = "\n".join([chunks[i] for i in indices[0]])

    # 4. Create prompt
    prompt = f"""
Answer the question using only the context below.

Context:
{context}

Question:
{question}
Answer:
"""

    # 5. Generate answer
    inputs = tokenizer(prompt, return_tensors="pt")

    outputs = model.generate(
        **inputs,
        max_new_tokens=50
    )

    answer = tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
    )
    return answer


print("Complete RAG pipeline ready!")
# Out:
# Complete RAG pipeline ready!

# %%
question = "How many paid leaves do employees get?"

answer = ask_rag(question)

print("Question:", question)
print("Answer:", answer)
# Out:
# Question: How many paid leaves do employees get?
# Answer: 20

# %%
import gradio as gr

def chatbot(question):
    return ask_rag(question)

demo = gr.Interface(
    fn=chatbot,
    inputs=gr.Textbox(
        label="Ask a question",
        placeholder="Ask something about the company policy..."
    ),
    outputs=gr.Textbox(label="Answer"),
    title="Company Policy RAG Chatbot",
    description="Ask questions about the company policy document."
)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://2c334672b0f774c832.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2c334672b0f774c832.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def ask_rag_with_source(question):

    query_embedding = embedding_model.encode([question])

    distances, indices = index.search(
        np.array(query_embedding).astype("float32"),
        k=2
    )

    context = "\n".join([chunks[i] for i in indices[0]])

    prompt = f"""
Answer the question using only the context below.

Context:
{context}
Question:
{question}

Answer:
"""

    inputs = tokenizer(prompt, return_tensors="pt")

    outputs = model.generate(
        **inputs,
        max_new_tokens=50
    )

    answer = tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
        )

    source = "company_policy.pdf | page 1"

    return answer, source

print("Source citation ready!")
# Out:
# Source citation ready!

# %%
answer, source = ask_rag_with_source(
    "How many paid leaves do employees get?"
)

print("Answer:", answer)
print("Source:", source)
# Out:
# Answer: 20
# Source: company_policy.pdf | page 1

# %%
import sqlite3

conn = sqlite3.connect("rag_database.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS chat_history (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    question TEXT,
    answer TEXT,
    source TEXT
)
""")

conn.commit()

print("SQL database created successfully!")
# Out:
# SQL database created successfully!

# %%
question = "How many paid leaves do employees get?"
answer = "20"
source = "company_policy.pdf | page 1"

cursor.execute("""
INSERT INTO chat_history (question, answer, source)
VALUES (?, ?, ?)
""", (question, answer, source))

conn.commit()

print("Chat saved successfully!")
# Out:
# Chat saved successfully!

# %%
cursor.execute("SELECT * FROM chat_history")

rows = cursor.fetchall()

for row in rows:
    print("ID:", row[0])
    print("Question:", row[1])
    print("Answer:", row[2])
    print("Source:", row[3])
    print("-------------------")
# Out:
# ID: 1
# Question: How many paid leaves do employees get?
# Answer: 20
# Source: company_policy.pdf | page 1
# -------------------

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    username TEXT UNIQUE,
    password TEXT,
    role TEXT
)
""")

conn.commit()

print("Users table created successfully!")
# Out:
# Users table created successfully!

# %%
cursor.execute("""
INSERT OR IGNORE INTO users (username, password, role)
VALUES (?, ?, ?)
""", ("admin", "admin123", "admin"))

cursor.execute("""
INSERT OR IGNORE INTO users (username, password, role)
VALUES (?, ?, ?)
""", ("user", "user123", "user"))

conn.commit()

print("Admin and User accounts created successfully!")
# Out:
# Admin and User accounts created successfully!

# %%
def login(username, password):

    cursor.execute("""
    SELECT role
    FROM users
    WHERE username = ? AND password = ?
    """, (username, password))

    result = cursor.fetchone()

    if result:
        return result[0]
    else:
        return None


role = login("admin", "admin123")

print("Login role:", role)
# Out:
# Login role: admin

# %%
chat_history = []
print("chat history ready!")
# Out:
# chat history ready!

# %%
def save_chat(question, answer):
    chat_history.append({
        "question": question,
        "answer": answer
    })

    print("Chat saved successfully!")

# %%
save_chat(
    "How many paid leaves do employees get?",
    "20"
)

print(chat_history)
# Out:
# Chat saved successfully!
# [{'question': 'How many paid leaves do employees get?', 'answer': '20'}]

# %%
def ask_rag_with_history(question):

    answer, source = ask_rag_with_source(question)

    save_chat(question, answer)

    return answer, source

print("RAG chat history function ready!")
# Out:
# RAG chat history function ready!

# %%
answer, source = ask_rag_with_history(
    "How many paid leaves do employees get?"
)

print("Answer:", answer)
print("Source:", source)
print("Chat History:")
print(chat_history)
# Out:
# Chat saved successfully!
# Answer: 20
# Source: company_policy.pdf | page 1
# Chat History:
# [{'question': 'How many paid leaves do employees get?', 'answer': '20'}, {'question': 'How many paid leaves do employees get?', 'answer': '20'}]

# %%
question = "How can employees apply for leave?"

answer, source = ask_rag_with_history(question)

print("Question:", question)
print("Answer:", answer)
print("Source:", source)
# Out:
# Chat saved successfully!
# Question: How can employees apply for leave?
# Answer: through the HR portal
# Source: company_policy.pdf | page 1

# %%
question = "Can employees request emergency leave?"

answer, source = ask_rag_with_history(question)

print("Question:", question)
print("Answer:", answer)
print("Source:", source)
# Out:
# Chat saved successfully!
# Question: Can employees request emergency leave?
# Answer: Yes
# Source: company_policy.pdf | page 1

# %%
question = "What is the company salary structure?"

answer, source = ask_rag_with_history(question)

print("Question:", question)
print("Answer:", answer)
print("Source:", source)
# Out:
# Chat saved successfully!
# Question: What is the company salary structure?
# Answer: 20
# Source: company_policy.pdf | page 1

# %%
def safe_chatbot(question):

    if not question.strip():
        return "Please enter a question."

    try:
        answer, source = ask_rag_with_history(question)

        return f"{answer}\n\nSource: {source}"

    except Exception as e:
        return f"Error: {str(e)}"

print("Error handling added!")
# Out:
# Error handling added!

# %%
result = safe_chatbot("")
print(result)
# Out:
# Please enter a question.
